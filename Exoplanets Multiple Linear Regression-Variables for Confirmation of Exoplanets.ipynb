# %%
# Import packages
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3 as sql

# %%
# Sklearn Evaluation Metrics
from sklearn import metrics
from sklearn.metrics import mean_squared_error, precision_score, confusion_matrix, accuracy_score

# %%
# Visualizes all the columns
pd.set_option('display.max_columns', None)

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
#Create the connection to the database file

database = "ExoplanetList.db"
conn = sqlite3.connect(database)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11684\2538941917.py in <module>
#       2
#       3 database = "ExoplanetList.db"
# ----> 4 conn = sqlite3.connect(database)
#
# NameError: name 'sqlite3' is not defined

# %%
query = '''SELECT * FROM Exoplanet List'''

# %%
df = pd.read_sql_query(query, connection)
df.head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    2022         try:
# -> 2023             cur.execute(*args, **kwargs)
#    2024             return cur
#
# OperationalError: no such table: Exoplanet
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11684\3327449464.py in <module>
# ----> 1 df = pd.read_sql_query(query, connection)
#       2 df.head()
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     398     """
#     399     pandas_sql = pandasSQL_builder(con)
# --> 400     return pandas_sql.read_query(
#     401         sql,
#     402         index_col=index_col,
# ...

# %%
# Import dataset
df = pd.read_csv('https://raw.githubusercontent.com/boggs2louky/Exoplanets_MLR/main/workingdata/cumulative_02102023.csv')

# %%
df.head()
# Out:
#       kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# 0  10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 1  10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 2  10811496  K00753.01           NaN       CANDIDATE        CANDIDATE
# 3  10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4  10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#    koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0      1.000              0              0              0              0
# 1      0.969              0              0              0              0
# 2      0.000              0              0              0              0
# 3      0.000              0              1              0              0
# 4      1.000              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# ...
